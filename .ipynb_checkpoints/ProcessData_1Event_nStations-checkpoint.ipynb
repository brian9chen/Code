# %%
from obspy import read, read_inventory 
from obspy.geodetics import degrees2kilometers
from obspy.signal import rotate
from obspy.signal.trigger import ar_pick

from scipy.io import savemat
from os.path import join as pjoin
import numpy as np
import matplotlib.pyplot as plt
plt.ioff()
# %matplotlib notebook

# %%
directory = '/Users/23brianc/Documents/Internship2020/Data/'
corrected_directory = '/Users/23brianc/Documents/Internship2020/Data/corrected/*'

# %% [markdown]
# # Read data

# %%
full_stream = read(corrected_directory)

# %%
inventory = read_inventory(directory+'inventory.xml',format='STATIONXML')

# %%
inventory
# Out:
# Inventory created at 2020-06-27T05:50:41.000000Z
# 	Created by: IRIS WEB SERVICE: fdsnws-station | version: 1.1.45
# 		    http://service.iris.edu/fdsnws/station/1/query?starttime=2005-06-20...
# 	Sending institution: IRIS-DMC (IRIS-DMC)
# 	Contains:
# 		Networks (7):
# 			CB, G, IC, II, KN, KZ, XF
# 		Stations (220):
# 			CB.CAD (Changdu, Tibet, China)
# 			CB.KSH (Kashi,Xingjiang)
# 			CB.NAQ (Naqu,Tibet,China)
# 			G.WUS (Wushi - Xinjiang Uygur, China)
# 			IC.LSA (Tibet, China)
# 			IC.WMQ (Urumqi, Xinjiang Province, China)
# 			II.AAK (Ala Archa, Kyrgyzstan)
# 			II.ABKT (Alibek, Turkmenistan)
# 			II.BRVK (Borovoye, Kazakhstan)
# 			II.KURK (Kurchatov, Kazakhstan)
# 			II.NIL (Nilore, Pakistan)
# 			KN.AAK (-)
# 			KN.AML (-)
# 			KN.CHM (-)
# 			KN.EKS2 (-)
# 			KN.KBK (-)
# 			KN.KZA (-)
# 			KN.NRPT (-)
# 			KN.TKM2 (-)
# 			KN.UCH (-)
# 			KN.ULHL (-)
# 			KN.USP (-)
# 			KZ.BRVK (Borovoye, Kazakstan)
# 			KZ.BVAR (Borovoye, Kazakstan)
# 			KZ.KKAR (Karatau array,KK31, Kazakhstan)
# 			KZ.KUR (Kurchatov, Kazakstan)
# 			KZ.KURK (Kurchatov, Kazakhstan)
# 			KZ.MAK (Makanchi, Kazakstan)
# 			KZ.MKAR (Makanchi array,MK31, Kazakhstan)
# 			KZ.PDG (Podgonoye, Kazakstan)
# 			KZ.VOS (Vostochnoye, Kazakstan)
# 			KZ.ZRN (Zerenda, Kazakstan)
# 			KZ.ZRNK (Zerenda, Kazakstan)
# 			XF.H0010 (H0010)
# 			XF.H0020 (H0020)
# 			XF.H0030 (H0030)
# 			XF.H0040 (H0040)
# 			XF.H0050 (H0050)
# 			XF.H0060 (H0060)
# 			XF.H0070 (H0070)
# 			XF.H0080 (H0080)
# 			XF.H0090 (H0090)
# 			XF.H0100 (H0100)
# 			XF.H0120 (H0120)
# 			XF.H0130 (H0130)
# 			XF.H0150 (H0150)
# 			XF.H0160 (H0160)
# 			XF.H0170 (H0170)
# 			XF.H0180 (H0180)
# 			XF.H0190 (H0190)
# 			XF.H0200 (H0200)
# 			XF.H0210 (H0210)
# 			XF.H0220 (H0220)
# 			XF.H0230 (H0230)
# 			XF.H0240 (H0240)
# 			XF.H0250 (H0250)
# 			XF.H0260 (H0260)
# 			XF.H0270 (H0270)
# 			XF.H0280 (H0280)
# 			XF.H0290 (H0290)
# 			XF.H0310 (H0310)
# 			XF.H0320 (H0320)
# 			XF.H0330 (H0330)
# 			XF.H0340 (H0340)
# 			XF.H0350 (H0350)
# 			XF.H0360 (H0360)
# 			XF.H0370 (H0370)
# 			XF.H0380 (H0380)
# 			XF.H0390 (H0390)
# 			XF.H0400 (H0400)
# 			XF.H0410 (H0410)
# 			XF.H0420 (H0420)
# 			XF.H0430 (H0430)
# 			XF.H0440 (H0440)
# 			XF.H0450 (H0450)
# 			XF.H0460 (H0460)
# 			XF.H0470 (H0470)
# 			XF.H0480 (H0480)
# 			XF.H0490 (H0490)
# 			XF.H0500 (H0500)
# 			XF.H0510 (H0510)
# 			XF.H0520 (H0520)
# 			XF.H0530 (H0530)
# 			XF.H0540 (H0540)
# 			XF.H0550 (H0550)
# 			XF.H0560 (H0560)
# 			XF.H0570 (H0570)
# 			XF.H0580 (H0580)
# 			XF.H0590 (H0590)
# 			XF.H0600 (H0600)
# 			XF.H0610 (H0610)
# 			XF.H0620 (H0620)
# 			XF.H0630 (H0630)
# 			XF.H0640 (H0640)
# 			XF.H0641 (H0641)
# 			XF.H0650 (H0650)
# 			XF.H0655 (H0655)
# 			XF.H0660 (H0660)
# 			XF.H0670 (H0670)
# 			XF.H0680 (H0680)
# 			XF.H0690 (H0690)
# 			XF.H0700 (H0700)
# 			XF.H0710 (H0710)
# 			XF.H0720 (H0720)
# 			XF.H0730 (H0730)
# 			XF.H0740 (H0740)
# 			XF.H0750 (H0750)
# 			XF.H0760 (H0760)
# 			XF.H0770 (H0770)
# 			XF.H0780 (H0780)
# 			XF.H0790 (H0790)
# 			XF.H0800 (H0800)
# 			XF.H0810 (H0810)
# 			XF.H1000 (H1000)
# 			XF.H1010 (H1010)
# 			XF.H1020 (H1020)
# 			XF.H1030 (H1030)
# 			XF.H1040 (H1040)
# 			XF.H1050 (H1050)
# 			XF.H1060 (H1060)
# 			XF.H1070 (H1070)
# 			XF.H1071 (H1071)
# 			XF.H1080 (H1080)
# 			XF.H1090 (H1090)
# 			XF.H1100 (H1100)
# 			XF.H1110 (H1110)
# 			XF.H1120 (H1120)
# 			XF.H1130 (H1130)
# 			XF.H1140 (H1140)
# 			XF.H1150 (H1150)
# 			XF.H1160 (H1160)
# 			XF.H1170 (H1170)
# 			XF.H1180 (H1180)
# 			XF.H1190 (H1190)
# 			XF.H1200 (H1200)
# 			XF.H1210 (H1210)
# 			XF.H1220 (H1220)
# 			XF.H1230 (H1230)
# 			XF.H1240 (H1240)
# 			XF.H1250 (H1250)
# 			XF.H1260 (H1260)
# 			XF.H1270 (H1270)
# 			XF.H1280 (H1280)
# 			XF.H1290 (H1290)
# 			XF.H1300 (H1300)
# 			XF.H1310 (H1310)
# 			XF.H1320 (H1320)
# 			XF.H1330 (H1330)
# 			XF.H1340 (H1340)
# 			XF.H1350 (H1350)
# 			XF.H1360 (H1360)
# 			XF.H1370 (H1370)
# 			XF.H1380 (H1380)
# 			XF.H1390 (H1390)
# 			XF.H1400 (H1400)
# 			XF.H1405 (H1405)
# 			XF.H1410 (H1410)
# 			XF.H1415 (H1415)
# 			XF.H1420 (H1420)
# 			XF.H1421 (H1421)
# 			XF.H1422 (H1422)
# 			XF.H1423 (H1423)
# 			XF.H1425 (H1425)
# 			XF.H1430 (H1430)
# 			XF.H1440 (H1440)
# 			XF.H1450 (H1450)
# 			XF.H1460 (H1460)
# 			XF.H1470 (H1470)
# 			XF.H1480 (H1480)
# 			XF.H1490 (H1490)
# 			XF.H1500 (H1500)
# 			XF.H1510 (H1510)
# 			XF.H1520 (H1520)
# 			XF.H1530 (H1530)
# 			XF.H1540 (H1540)
# 			XF.H1550 (H1550)
# 			XF.H1560 (H1560)
# 			XF.H1570 (H1570)
# 			XF.H1580 (H1580)
# 			XF.H1590 (H1590)
# 			XF.H1600 (H1600)
# 			XF.H1610 (H1610)
# 			XF.H1620 (H1620)
# 			XF.H1630 (H1630)
# 			XF.NBENS (NBENS)
# 			XF.NBIRA (NBIRA)
# 			XF.NBUNG (NBUNG)
# 			XF.NDOML (NDOML)
# 			XF.NG010 (NG010)
# 			XF.NG020 (NG020)
# 			XF.NG030 (NG030)
# 			XF.NG040 (NG040)
# 			XF.NG050 (NG050)
# 			XF.NG060 (NG060)
# 			XF.NGUMB (NGUMB)
# 			XF.NHILE (NHILE)
# 			XF.NJANA (NJANA)
# 			XF.NKDMG (NKDMG)
# 			XF.NNAMC (NNAMC)
# 			XF.NP010 (NP010)
# 			XF.NP020 (NP020)
# 			XF.NP030 (NP030)
# 			XF.NP035 (NP035)
# 			XF.NP040 (NP040)
# 			XF.NP050 (NP050)
# 			XF.NP060 (NP060)
# 			XF.NP070 (NP070)
# 			XF.NP071 (NP071)
# 			XF.NP075 (NP075)
# 			XF.NP080 (NP080)
# 			XF.NP082 (NP082)
# 			XF.NP085 (NP085)
# 			XF.NP090 (NP090)
# 			XF.NP100 (NP100)
# 			XF.NPHAP (NPHAP)
# 			XF.NRUMJ (NRUMJ)
# 			XF.NSIND (NSIND)
# 			XF.NSUKT (NSUKT)
# 			XF.NTHAK (NTHAK)
# 			XF.NTUML (NTUML)
# 		Channels (990):
# 			CB.CAD.00.BHZ, CB.CAD.00.BHN, CB.CAD.00.BHE, CB.KSH.00.BHZ,
# 			CB.KSH.00.BHN, CB.KSH.00.BHE, CB.NAQ.00.BHZ, CB.NAQ.00.BHN,
# 			CB.NAQ.00.BHE, G.WUS.00.BHZ, G.WUS.00.BHN, G.WUS.00.BHE,
# 			IC.LSA.00.BHZ, IC.LSA.00.BHN, IC.LSA.00.BHE, IC.LSA.10.BHZ,
# 			IC.LSA.10.BHN, IC.LSA.10.BHE, IC.WMQ.00.BHZ, IC.WMQ.00.BHN,
# 			IC.WMQ.00.BHE, IC.WMQ.10.BHZ, IC.WMQ.10.BHN, IC.WMQ.10.BHE,
# 			II.AAK.00.BHZ, II.AAK.00.BHN, II.AAK.00.BHE, II.ABKT.00.BHZ,
# 			II.ABKT.00.BHN, II.ABKT.00.BHE, II.BRVK.00.BHZ, II.BRVK.00.BHN,
# 			II.BRVK.00.BHE, II.KURK.00.BHZ, II.KURK.00.BHN, II.KURK.00.BHE,
# 			XF.H1580..BHE, XF.H1580.01.BHZ, XF.H1580.01.BHN, XF.H1580.01.BHE,
# 			XF.H1590..BHZ, XF.H1590..BHN, XF.H1590..BHE, XF.H1590.01.BHZ,
# 			XF.H1590.01.BHN, XF.H1590.01.BHE, XF.H1600..BHZ, XF.H1600..BHN,
# 			XF.H1600..BHE, XF.H1600.01.BHZ, XF.H1600.01.BHN, XF.H1600.01.BHE,
# 			XF.H1610..BHZ, XF.H1610..BHN, XF.H1610..BHE, XF.H1610.01.BHZ,
# 			XF.H1610.01.BHN, XF.H1610.01.BHE, XF.H1620..BHZ, XF.H1620..BHN,
# 			XF.H1620..BHE, XF.H1620.01.BHZ, XF.H1620.01.BHN, XF.H1620.01.BHE,
# 			XF.H1630..BHZ, XF.H1630..BHN, XF.H1630..BHE, XF.H1630.01.BHZ,
# 			XF.H1630.01.BHN, XF.H1630.01.BHE, XF.NBENS.01.BHZ, XF.NBENS.01.BHN
# 			XF.NBENS.01.BHE, XF.NBIRA.01.BHZ, XF.NBIRA.01.BHN,
# 			XF.NBIRA.01.BHE, XF.NBUNG.01.BHZ, XF.NBUNG.01.BHN, XF.NBUNG.01.BHE
# 			XF.NDOML.01.BHZ, XF.NDOML.01.BHN, XF.NDOML.01.BHE,
# 			XF.NG010.01.BHZ, XF.NG010.01.BHN, XF.NG010.01.BHE, XF.NG020.01.BHZ
# 			XF.NG020.01.BHN, XF.NG020.01.BHE, XF.NG030.01.BHZ,
# 			XF.NG030.01.BHN, XF.NG030.01.BHE, XF.NG040.01.BHZ, XF.NG040.01.BHN
# 			XF.NG040.01.BHE, XF.NG050.01.BHZ, XF.NG050.01.BHN,
# 			XF.NG050.01.BHE, XF.NG060.01.BHZ, XF.NG060.01.BHN, XF.NG060.01.BHE
# 			XF.NGUMB.01.BHZ, XF.NGUMB.01.BHN, XF.NGUMB.01.BHE,
# 			XF.NHILE.01.BHZ, XF.NHILE.01.BHN, XF.NHILE.01.BHE, XF.NJANA.01.BHZ
# 			XF.NJANA.01.BHN, XF.NJANA.01.BHE, XF.NKDMG.01.BHZ,
# 			XF.NKDMG.01.BHN, XF.NKDMG.01.BHE, XF.NNAMC.01.BHZ, XF.NNAMC.01.BHN
# 			XF.NNAMC.01.BHE, XF.NP010.01.BHZ, XF.NP010.01.BHN,
# 			XF.NP010.01.BHE, XF.NP020.01.BHZ, XF.NP020.01.BHN, XF.NP020.01.BHE
# 			XF.NP030.01.BHZ, XF.NP030.01.BHN, XF.NP030.01.BHE,
# 			XF.NP035.01.BHZ, XF.NP035.01.BHN, XF.NP035.01.BHE, XF.NP040.01.BHZ
# 			XF.NP040.01.BHN, XF.NP040.01.BHE, XF.NP050.01.BHZ,
# 			XF.NP050.01.BHN, XF.NP050.01.BHE, XF.NP060.01.BHZ, XF.NP060.01.BHN
# 			XF.NP060.01.BHE, XF.NP070.01.BHZ, XF.NP070.01.BHN,
# 			XF.NP070.01.BHE, XF.NP071.01.BHZ, XF.NP071.01.BHN, XF.NP071.01.BHE
# 			XF.NP075.01.BHZ, XF.NP075.01.BHN, XF.NP075.01.BHE,
# 			XF.NP080.01.BHZ, XF.NP080.01.BHN, XF.NP080.01.BHE, XF.NP082.01.BHZ
# 			XF.NP082.01.BHN, XF.NP082.01.BHE, XF.NP085.01.BHZ,
# 			XF.NP085.01.BHN, XF.NP085.01.BHE, XF.NP090.01.BHZ, XF.NP090.01.BHN
# 			XF.NP090.01.BHE, XF.NP100.01.BHZ, XF.NP100.01.BHN,
# 			XF.NP100.01.BHE, XF.NPHAP.01.BHZ, XF.NPHAP.01.BHN, XF.NPHAP.01.BHE
# 			XF.NRUMJ.01.BHZ, XF.NRUMJ.01.BHN, XF.NRUMJ.01.BHE,
# 			XF.NSIND.01.BHZ, XF.NSIND.01.BHN, XF.NSIND.01.BHE, XF.NSUKT.01.BHZ
# 			XF.NSUKT.01.BHN, XF.NSUKT.01.BHE, XF.NTHAK.01.BHZ,
# 			XF.NTHAK.01.BHN, XF.NTHAK.01.BHE, XF.NTUML.01.BHZ, XF.NTUML.01.BHN
# 			XF.NTUML.01.BHE

# %% [markdown]
# # Process Data

# %%
i = 0

t_stations = np.empty((7*220), dtype=type(inventory[0][0][0]))
Z_stations = np.empty((7*220), dtype=type(inventory[0][0][0]))
R_stations = np.empty((7*220), dtype=type(inventory[0][0][0]))
T_stations = np.empty((7*220), dtype=type(inventory[0][0][0]))

for net in inventory[:]:
    for stn in net[:]:
        
        stn_stream = full_stream.select(network=net.code,station=stn.code)
        
        if len(stn_stream) > 3:
            print('There are more than 1 location for station '+net.code+'.'+stn.code+' !!')
        elif len(stn_stream) == 3:
            E = stn_stream[0]
            N = stn_stream[1]
            Z = stn_stream[2]
            
            ## Basic parameters  
            # original sample rate (s)
            dt_in= E.stats.sac['delta']
            # begin time
            b_in = E.stats.sac['b']
            # number of points
            npts_in = E.stats.sac['npts']
            # event origin time
            o_in = E.stats.sac['o']
            # end time
            e_in = b_in+(npts_in-1)*dt_in
            # full time series
            T = np.arange(b_in, e_in, dt_in)
            
            # station locations
            stlo = E.stats.sac['stlo']
            stla = E.stats.sac['stla']
            
            # epicentral distance (angle)
            gcarc = E.stats.sac['gcarc']
            
            # epicentral distance (km)
            dist = degrees2kilometers(E.stats.sac['gcarc'])
            
            # back-azimuth
            baz = E.stats.sac['baz']
            
            ## Rotation
            r_data, t_data = rotate.rotate_ne_rt(N.data,E.data,baz)
            N.data = r_data
            E.data = t_data
            R = N
            T = E
            
            ## Resample at sample_rate (s)
            dt_out = 0.01
            if dt_in != dt_out:
                Z.interpolate(100,method='cubic')
                R.interpolate(100,method='cubic')
                T.interpolate(100,method='cubic')
            
            # new full time series
            t_shift = b_in-dt_out
            t_start = dt_out
            t_end = e_in-t_shift
            t = np.arange(0,t_end,dt_out)
            
            ## Bandpass filter
            Z_filt = Z.copy()
            R_filt = R.copy()
            T_filt = T.copy()
            Z_filt.filter('bandpass',freqmin=1,freqmax=2,corners=2)
            R_filt.filter('bandpass',freqmin=1,freqmax=2,corners=2)
            T_filt.filter('bandpass',freqmin=1,freqmax=2,corners=2)
            
            t_stations[i] = t
            Z_stations[i] = Z_filt
            R_stations[i] = R_filt
            T_stations[i] = T_filt
            
            i = i+1
# Out:
# There are more than 1 location for station IC.LSA !!
# There are more than 1 location for station IC.WMQ !!

# %%
i
# Out:
# 74

# %% [markdown]
# # P-Arrival

# %%
#STA and LTA parameters
p_sta = 1
p_lta = 0.1
s_sta = 4.0
s_lta = 1.0

#Sampling rate of filtered data
df = Z_filt.stats.sampling_rate

#parameters from: https://docs.obspy.org/tutorial/code_snippets/trigger_tutorial.html
t_both = ar_pick(Z_filt,R_filt,T_filt, df, 1, 2, p_sta, p_lta, s_sta, s_lta, 2, 8, 0.1 ,0.2, True) 

tp = t_both[0]

#the arrival of the p-wave in seconds
tp = 1000

# %% [markdown]
# # Calculate Windows

# %%
import math
from matplotlib import pyplot as plt

#velocities of Sn and Lg
vsn = 4.0
vlg = 2.8

vsn_max = 4.8
vlg_max = 3.6

if dist > 300:
    vpn = 8.1
    tsn_diff = dist*(1/vsn-1/vpn)
    tlg_diff = dist*(1/vlg-1/vpn)
    
    tsn_diff_min = dist*(1/vsn_max-1/vpn)
    tlg_diff_min = dist*(1/vlg_max-1/vpn)
    
elif dist < 300:
    vp = 6.4;
    tsn_diff = dist*(1/vsn-1/vp)
    tlg_diff = dist*(1/vlg-1/vp)
    
    tsn_diff_min = dist*(1/vsn_max-1/vp)
    tlg_diff_min = dist*(1/vlg_max-1/vp)
    
#Sn and Lg windows
tsn = tsn_diff+tp;
tlg = tlg_diff+tp;

tsn_min = tsn_diff_min+tp
tlg_min = tlg_diff_min+tp

#getting the ceiling so that they can be used as indices
ntp = math.ceil(tp/dt_out)
ntsn = math.ceil(tsn/dt_out)
ntlg = math.ceil(tlg/dt_out)

ntsn_min = math.ceil(tsn_min/dt_out)
ntlg_min = math.ceil(tlg_min/dt_out)

n = 10

window_Sn_stations = np.empty((i), dtype=np.ndarray)
window_Lg_stations = np.empty((i), dtype=np.ndarray)
window_noise_stations = np.empty((i), dtype=np.ndarray)

for x in range(i):
    #getting the windows for Sn, Lg, and noise as subarrays
    index = x #which station to plot
    
    window_time_Sn = t_stations[index][ntsn_min:ntsn]
    window_Sn_stations[x] = T_stations[index][ntsn_min:ntsn]
    
    window_time_Lg = t_stations[index][ntlg_min:ntlg]
    window_Lg_stations[x] = T_stations[index][ntlg_min:ntlg]
    
    ntn = math.ceil((tp-5)/dt_out)
    ntn_min = math.ceil((tp-25)/dt_out)

    window_time_noise = t_stations[index][ntn_min:ntn]
    window_noise_stations[x] = T_stations[index][ntn_min:ntn]

    time = t_stations[index][0:T_stations[index].data.size]

    #plotting the original data in black, the Sn window in red, and the Lg window in blue

    #plt.subplot(i, 1, index+1)
    
    plt.plot(time, T_stations[index], 'k', linewidth = 0.2)

    plt.plot(window_time_Sn, window_Sn_stations[x], 'r', linewidth = 0.2)

    plt.plot(window_time_Lg, window_Lg_stations[x], 'b', linewidth = 0.2)

    plt.plot(window_time_noise, window_noise_stations[x], 'g', linewidth = 0.2)

#     plt.show()
    plt.savefig(fname = '/Users/23brianc/Documents/Internship2020/Figures/station_plots/' +str(x + 1), dpi = 500)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
window_Sn_stations[i-1].size
# Out:
# 2565

# %% [markdown]
# # Compare Amplitudes

# %%
#root mean square function
def rms(arr, n): 
    square = 0
    mean = 0.0
    root = 0.0
      
    #Calculate square 
    for i in range(0,n): 
        square += (arr[i]**2) 
      
    #Calculate Mean  
    mean = (square / (float)(n)) 
      
    #Calculate Root 
    root = math.sqrt(mean) 
      
    return root 

SNRsn_stations = np.empty((i), dtype=np.ndarray)
SNRlg_stations = np.empty((i), dtype=np.ndarray)
ampr_stations = np.empty((i), dtype=np.ndarray)

for x in range(i):
    #signal to noise ratio
    if window_Sn_stations[x].size==0:
        continue
        
    if window_Lg_stations[x].size==0:
        continue
    
    if window_noise_stations[x].size==0:
        continue
    
    sn_amp = rms(window_Sn_stations[x], window_Sn_stations[x].size)
    lg_amp = rms(window_Lg_stations[x], window_Lg_stations[x].size)
    
    noise = rms(window_noise_stations[x], window_noise_stations[x].size);
    
    SNRsn_stations[x] = sn_amp/noise
    SNRlg_stations[x] = lg_amp/noise
    
    #if SNRsn < 4 & SNRlg < 4:
    
    ampr_stations[x] = sn_amp/lg_amp
    
#Sn/Lg amplitude ratio
ampr_stations
# Out:
# array([0.6717608733693413, 1.138152200698781, 0.9012109748936346,
#        4.96497837603776, None, 0.9032899584831032, 0.4973713874602175,
#        0.755272853635606, 0.5217064755732067, None, 0.8334149882971673,
#        0.668671602591113, 1.2532432950563006, 0.5540351457694059,
#        1.3395170523487256, 0.4661124051149981, 1.6059333422659947,
#        1.8857193098562277, 0.5376774396300587, 0.6818413661716497,
#        0.8974146857242574, 0.8149224562294465, 0.6972154502307433,
#        0.7660171238714059, 0.8420627785270776, 0.8812216126067499,
#        0.8394077870175223, 0.5885444196159733, 1.0867821722047786,
#        0.97006621298666, 0.4393200333891873, 0.3812272070681034,
#        0.31840599147470056, 0.47800678588247414, 0.46937186907547573,
#        0.43304682894358526, 0.41430199654689803, 0.5640323961625553,
#        0.3163759150782555, 0.41649442672105536, 0.4546417801452229,
#        0.3757193988766146, 0.44216409688646313, 0.3677767150244678,
#        0.4119877804259907, 0.47701322368768156, 0.44089116007034557,
#        0.5855016944947854, 0.47304409446654083, 1.0358680520021226,
#        0.7606592842193062, 0.4524296515794507, 0.6553628305907366,
#        0.6358106261586748, 0.8342276563541428, 0.8958838713094548,
#        0.8369544932002785, 0.8182841244001112, 0.7624799071685852,
#        0.7563205266726712, 1.1296531714826257, 0.7768600828810968,
#        1.2337988775111153, 1.2179109781141082, 1.7831405738677082,
#        1.1398609755444986, 1.8101984263472501, 1.5749603004823265,
#        1.584585132679225, 1.948615362644175, 2.135010731724957,
#        1.93011279666504, 2.4219047717105244, 2.1306826793473794], dtype=object)

# %% [markdown]
# # Save processed data

# %%
mdict = {}
mdict['Z'] = Z_filt.data
mdict['R'] = R_filt.data
mdict['T'] = T_filt.data
mdict['t'] = t

# %%
# matfile_name = pjoin(corrected_directory,'last_trace.mat') #pjoin joins the path of two directories with '/'

matfile_name = corrected_directory + 'last_trace.mat' #equivalent of previous line
savemat(matfile_name,mdict)
